# %% [markdown]
# <a href="https://colab.research.google.com/github/Nicolaser1102/Inferencia_estadistica/blob/main/Tareas_Week4/Trazado_de_matriz_de_confusion.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # CODING DOJO
# ## Fecha creación:30/1/2022
# ## Fecha de actualización: 30/1/2022
# ## Esteban Simbaña
#
# # Trazado de matriz de confusión

# %% [markdown]
# ##Tarea
# ![a.png](data:image/png;base64,...)
#
# ![a2.png](data:image/png;base64,...)

# %% [markdown]
# Importamos las librerías que necesitaremos

# %%
import pandas as pd
import seaborn as sns 
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# ## Trazado de matriz de confusión utilizando librería pandas

# %%
#Primero se creará la matriz de confusión
datos_df = {} #se crea un diccionario
datos_df['Predicted 0'] = [87,17] 

#añadimos la primera columna a la df
df = pd.DataFrame(data=datos_df)
df
# Out:
#    Predicted 0
# 0           87
# 1           17

# %%
#se añade la segunda columna al df
datos_df['Predicted 1'] = [16,59]
datos_df
df = pd.DataFrame(data=datos_df)
df
# Out:
#    Predicted 0  Predicted 1
# 0           87           16
# 1           17           59

# %%
#renombramos el nombre de las filas 
df= df.rename(index={0:'Actually 0',1:'Actually 1'})
df
# Out:
#             Predicted 0  Predicted 1
# Actually 0           87           16
# Actually 1           17           59

# %%
#creamos el primer mapa de calor 
heat_map = sns.heatmap(df)

# %%
#cambiamos color del 'mapa de calor'
heat_map = sns.heatmap(df,cmap='Blues')

# %%
## se cambian el nombre de las columnas y filas en '0' y '1' para parecerse al gráfico
df = df.rename(columns={'Predicted 0':'0','Predicted 1':'1'})
df= df.rename(index={'Actually 0':'0','Actually 1':'1'})

# %%
#trazamos de nuevo el mapa de calor

heat_map = sns.heatmap(df,cmap='Blues', edgecolor = "black",annot=True)
##(annot = True), mostrará los números dentro de cada cuadro 
heat_map = sns.set(font_scale=1) #ajustamos tamaño de la fuente
pass

# %%
#realizamos cambios 

#trazamos de nuevo el mapa de calor
heat_map = sns.heatmap(df,cmap='Blues', edgecolor = "black",annot=True,linewidths=0.8, linecolor='black')
##(annot = True), mostrará los números dentro de cada cuadro 
heat_map = sns.set(font_scale=1) #ajustamos tamaño de la fuente

plt.xlabel("Predicted label") #cambiamos el valor de 'label' en X
plt.ylabel("True label") #cambiamos el valor de 'label' en y
plt.grid(axis='y')
pass

# %%
#realizmos cambios finales
#trazamos de nuevo el mapa de calor

#se añaden 'ticks'
sns.set()
sns.set_style("ticks")

plt.figure(figsize=(10,7))
heat_map = sns.heatmap(df,cmap='Blues', edgecolor = "black",annot=True,linewidths=1, linecolor='k',yticklabels=True)
##(annot = True), mostrará los números dentro de cada cuadro 
heat_map = sns.set(font_scale=1.7) #ajustamos tamaño de la fuente

plt.xlabel("Predicted label",fontsize=15,) #cambiamos el valor de 'label' en X
plt.ylabel("True label",fontsize=15) #cambiamos el valor de 'label' en y
plt.grid(axis='x')
plt.yticks(rotation = 0)
pass

# %% [markdown]
# ## Trazado de matriz de confusión usando librería Numpy

# %%
#creamos un array en numpy
a = np.array([[87,16],[17,59]])
a
# Out:
# array([[87, 16],
#        [17, 59]])

# %%
#utilizamos el mismo array para utilizarlo en el gráfico mapa de calor 
df_numpy= np.array([[87,16],[17,59]])

# %%
##utilizamos la misma personalizacion de la grafica anterior

plt.figure(figsize=(10,7))

#se añaden 'ticks'
sns.set()
sns.set_style("ticks")

heat_map = sns.heatmap(df_numpy,cmap='Blues', edgecolor = "black",annot=True,linewidths=0.7, linecolor='k')
##(annot = True), mostrará los números dentro de cada cuadro 
heat_map = sns.set(font_scale=1.7) #ajustamos tamaño de la fuente

plt.xlabel("Predicted label",fontsize=13) #cambiamos el valor de 'label' en X
plt.ylabel("True label",fontsize=13) #cambiamos el valor de 'label' en y
plt.grid(axis='x')
plt.yticks(rotation = 0)
pass
